# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras.utils import plot_model

print(tf.__version__)
# Out:
# 2.12.0

# %%
import matplotlib.pyplot as plt ## matplotlib allows us to draw graphs.
import seaborn as sns ## seaborn makes it easier to draw nice-looking graphs.

# %%
# Build a simple Sequential model
#keras makes it really easy to define neural networks
#keras is API of tensorflow
#A neural network is basically a set of functions which can learn patterns

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
# Visualize the model
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
# Compile the model
#first make a guse measure how good and bad the guse with the loss function, use the optimizer and the data to make another gues and repeat this
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Declare model inputs and outputs for training
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# Train the model
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 286ms/step - loss: 1.7035
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4799
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3011
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1576
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0420
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9484
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8720
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8094
# Epoch 9/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7576
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7143
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6779
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6468
# ...

# %%
# Make a prediction
print(model.predict([5]))
# Out:
# 1/1 [==============================] - 0s 92ms/step
# [[8.996144]]

# %%
# Your input values
input_values = np.array([-1.0000, -0.9592, -0.9184, -0.8776, -0.8367, -0.7959, -0.7551, -0.7143,
        -0.6735, -0.6327, -0.5918, -0.5510, -0.5102, -0.4694, -0.4286, -0.3878,
        -0.3469, -0.3061, -0.2653, -0.2245, -0.1837, -0.1429, -0.1020, -0.0612,
        -0.0204,  0.0204,  0.0612,  0.1020,  0.1429,  0.1837,  0.2245,  0.2653,
         0.3061,  0.3469,  0.3878,  0.4286,  0.4694,  0.5102,  0.5510,  0.5918,
         0.6327,  0.6735,  0.7143,  0.7551,  0.7959,  0.8367,  0.8776,  0.9184,
         0.9592,  1.0000])

# Your output values (Replace [...] with the actual output values predicted by the model)
output_values = model.predict(input_values)

# Convert input_values and output_values to 1-dimensional arrays using numpy
input_values = input_values.flatten()
output_values = output_values.flatten()

sns.set(style="whitegrid")

## create the graph (you might not see it at this point, but you will after we save it as a PDF).
sns.lineplot(x=input_values,
             y=output_values,
             color='green',
             linewidth=2.5)

## now label the y- and x-axes.
plt.ylabel('y')
plt.xlabel('x')

## optionally, save the graph as a PDF.
# plt.savefig('BasicNN.pdf')
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f12c65b0ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step
# Text(0.5, 0, 'x')
